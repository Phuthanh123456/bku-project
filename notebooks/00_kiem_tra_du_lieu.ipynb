# %% [markdown]
# # Kiểm tra dữ liệu IWSLT**TASK 02-04 (My)**Nội dung cần có:- Xem vài cặp câu thô- Vẽ histogram phân bố độ dài câu (En và Vi)- Kiểm bảng thống kê lọc- In một batch mẫu: kích thước, padding mask, causal mask

# %%
import sys
sys.path.insert(0, '../src')

from nmt.utils import nap_config, dat_seed

cfg = nap_config('../configs/base.yaml')
dat_seed(cfg.thi_nghiem.seed, cfg.thi_nghiem.deterministic)
cfg.thi_nghiem.ten
