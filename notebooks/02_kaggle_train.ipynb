# %% [markdown]
# # Notebook chạy trên Kaggle**TASK 11-15 (Bảo, Quân)**Nội dung cần có:- Đọc HF_TOKEN từ Kaggle Secrets (KHÔNG viết token vào ô code)- Thử tải checkpoint mới nhất từ HF Hub, có thì chạy tiếp, không thì khởi tạo mới- Chạy vòng huấn luyện, cứ N bước thì lưu checkpoint và đẩy lên Hub- Nhớ đẩy CẢ thư mục log lên, nếu không thì kernel chết là mất log

# %%
import sys
sys.path.insert(0, '../src')

from nmt.utils import nap_config, dat_seed

cfg = nap_config('../configs/base.yaml')
dat_seed(cfg.thi_nghiem.seed, cfg.thi_nghiem.deterministic)
cfg.thi_nghiem.ten
