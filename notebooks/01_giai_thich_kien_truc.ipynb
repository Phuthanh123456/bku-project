# %% [markdown]
# # Giải thích kiến trúc**TASK 05-09 (Bảo, Quân)**Nội dung cần có:- Vẽ hình minh họa tính chất RoPE (hai đường phải trùng nhau)- Bản đồ nhiệt trọng số attention- Đếm tham số theo từng thành phần- So RMSNorm tự viết với torch.nn.RMSNorm

# %%
import sys
sys.path.insert(0, '../src')

from nmt.utils import nap_config, dat_seed

cfg = nap_config('../configs/base.yaml')
dat_seed(cfg.thi_nghiem.seed, cfg.thi_nghiem.deterministic)
cfg.thi_nghiem.ten
